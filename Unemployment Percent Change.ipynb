# %%
import numpy as np
import pandas as pd
path = r'C:\Users\jemcl\Desktop\College Notes\10. Spring 2023\CSCI 334\Final Project\Unemployment in America Per US State.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#    FIPS Code  State/Area  Year  Month  \
# 0          1     Alabama  1976      1
# 1          2      Alaska  1976      1
# 2          4     Arizona  1976      1
# 3          5    Arkansas  1976      1
# 4          6  California  1976      1
#
#   Total Civilian Non-Institutional Population in State/Area  \
# 0                                       2,605,000
# 1                                         232,000
# 2                                       1,621,000
# 3                                       1,536,000
# 4                                      15,621,000
#
#   Total Civilian Labor Force in State/Area  \
# 0                             1,484,555
# 1                               160,183
# 2                               964,120
# 3                               889,044
# 4                             9,774,280
#
#    Percent (%) of State/Area's Population Total Employment in State/Area  \
# 0                                    57.0                   1,386,023
# ...

# %%
years = data['Year'].unique()
# Out:
# array([1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986,
#        1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997,
#        1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019,
#        2020, 2021, 2022], dtype=int64)

# %%
data[(data['Year'] == 1999) & (data['Month'] == 1)]
# Out:
#        FIPS Code            State/Area  Year  Month  \
# 14628          1               Alabama  1999      1
# 14629          2                Alaska  1999      1
# 14630          4               Arizona  1999      1
# 14631          5              Arkansas  1999      1
# 14632          6            California  1999      1
# 14633         37    Los Angeles County  1999      1
# 14634          8              Colorado  1999      1
# 14635          9           Connecticut  1999      1
# 14636         10              Delaware  1999      1
# 14637         11  District of Columbia  1999      1
# 14638         12               Florida  1999      1
# 14639         13               Georgia  1999      1
# 14640         15                Hawaii  1999      1
# 14641         16                 Idaho  1999      1
# 14642         17              Illinois  1999      1
# 14643         18               Indiana  1999      1
# 14644         19                  Iowa  1999      1
# ...

# %%
data['State/Area'] == 'Alabama'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29887    False
# 29888    False
# 29889    False
# 29890    False
# 29891    False
# Name: State/Area, Length: 29892, dtype: bool

# %%
# Aggregating State unemployment averages
stateAvgs = pd.DataFrame(columns=['State/Area', 'Year', 'Percent Unemployment Average', 'Percent Change'] )

# %%
stateAvgs
# Out:
# Empty DataFrame
# Columns: [State/Area, Year, Percent Unemployment Average, Percent Change]
# Index: []

# %%
states = data['State/Area'].unique()
years = data['Year'].unique()
index = 0
for year in years:
    for state in states:
        # monthDat = data[(data['Year'] == year) & (data['State/Area'] == state)]
        unemployment = data[(data['Year'] == year) & (data['State/Area'] == state)]['Percent (%) of Labor Force Unemployed in State/Area'].mean()
        stateAvgs.loc[index] = [state, year, unemployment, 0 ]
        index+=1
        #print(year)
        #print(state)
        #print( data[(data['Year'] == year) & (data['State/Area'] == state)]['Percent (%) of Labor Force Unemployed in State/Area'].mean() )

# %%
path = r'C:\Users\jemcl\Desktop\College Notes\10. Spring 2023\CSCI 334\Final Project\test.csv'
stateAvg.to_csv(path)

# %%
stateAvg = round(stateAvgs,2)
stateAvg
#stateAvg[stateAvg['State/Area'] == 'Alabama'].to_csv(path)
# Out:
#          State/Area  Year  Percent Unemployment Average  Percent Change
# 0           Alabama  1976                          6.70               0
# 1            Alaska  1976                          7.57               0
# 2           Arizona  1976                          9.76               0
# 3          Arkansas  1976                          6.92               0
# 4        California  1976                          9.15               0
# ...             ...   ...                           ...             ...
# 2486       Virginia  2022                          2.83               0
# 2487     Washington  2022                          4.18               0
# 2488  West Virginia  2022                          3.92               0
# 2489      Wisconsin  2022                          2.93               0
# 2490        Wyoming  2022                          3.57               0
#
# [2491 rows x 4 columns]

# %%
stateAvg.iloc[0,3]
# Out:
# 0

# %%
index = 53
for year in range(1977, 2023):
    for state in states:
        y2 = (stateAvg[(stateAvg['Year'] == (year-1)) & (stateAvg['State/Area'] == state)]['Percent Unemployment Average']) 
        y1 = (stateAvg[(stateAvg['Year'] == (year)) & (stateAvg['State/Area'] == state)]['Percent Unemployment Average'])
        stateAvg.iloc[index,3] = round(y1.values[0] - y2.values[0],2)
        index+=1
        print(round(y1.values[0] - y2.values[0],2))
# Out:
# 0.45
# 2.32
# -1.36
# -0.44
# -0.76
# -0.77
# 0.43
# -2.18
# -0.42
# 0.0
# -1.02
# -1.23
# -1.58
# 0.2
# -0.36
# -0.26
# -0.07
# -0.27
# -0.57
# 0.29
# -0.29
# -0.44
# -1.87
# -1.17
# -0.52
# 0.72
# -0.16
# 0.27
# 0.22
# -2.05
# -0.85
# -1.1
# -0.99
# -1.04
# -0.9
# -0.3
# 0.68
# -1.26
# -0.81
# -1.84
# -0.27
# 0.03
# -0.29
# 0.06
# 0.17
# -0.39
# -0.4
# -1.25
# -0.42
# -0.4
# -0.3
# -0.45
# -0.62
# -0.74
# 0.74
# -2.45
# -0.26
# -1.26
# -1.24
# -0.79
# -1.7
# -1.1
# -0.83
# -1.52
# -1.24
# -0.68
# -0.36
# -0.21
# -0.22
# -0.17
# -0.84
# 0.2
# -0.13
# -1.94
# -0.5
# -1.71
# -1.2
# -1.37
# -0.46
# -1.12
# -0.58
# -0.4
# -2.35
# -1.75
# -2.04
# -1.54
# -1.46
# -1.23
# -1.35
# -0.31
# -0.94
# -1.45
# -1.31
# -0.73
# -1.73
# -1.17
# -0.22
# -0.43
# -0.56
# -1.34
# -1.35
# -0.17
# -1.57
# -0.58
# -0.19
# -0.38
# 0.82
# -1.57
# -0.87
# 0.06
# -0.91
# -1.23
# -0.94
# -0.21
# -0.1
# -0.95
# -0.77
# -0.56
# -1.22
# 0.33
# -0.4
# 0.88
# 0.34
# 0.07
# 0.48
# -0.15
# 0.2
# 0.17
# -0.68
# 0.84
# ...

# %%
stateAvg
# Out:
#          State/Area  Year  Percent Unemployment Average  Percent Change
# 0           Alabama  1976                          6.70            0.00
# 1            Alaska  1976                          7.57            0.00
# 2           Arizona  1976                          9.76            0.00
# 3          Arkansas  1976                          6.92            0.00
# 4        California  1976                          9.15            0.00
# ...             ...   ...                           ...             ...
# 2486       Virginia  2022                          2.83           -1.05
# 2487     Washington  2022                          4.18           -1.03
# 2488  West Virginia  2022                          3.92           -1.19
# 2489      Wisconsin  2022                          2.93           -0.91
# 2490        Wyoming  2022                          3.57           -1.05
#
# [2491 rows x 4 columns]

# %%
path = r'C:\Users\jemcl\Desktop\College Notes\10. Spring 2023\CSCI 334\Final Project\Yearly Percent Change by State .csv'
stateAvg.to_csv(path)

# %%
# Out:
# 7.32
